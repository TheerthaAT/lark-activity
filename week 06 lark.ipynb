# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\user\Desktop\Dataset_w6.xlsx")

# %%
data
# Out:
#                                 country             Region  \
# 0                           Afghanistan       SouthernAsia
# 1                               Albania     SouthernEurope
# 2                               Algeria     NorthernAfrica
# 3                                Angola       MiddleAfrica
# 4                   Antigua and Barbuda          Caribbean
# ..                                  ...                ...
# 191  Venezuela (Bolivarian Republic of)       SouthAmerica
# 192                            Viet Nam  South-easternAsia
# 193                               Yemen        WesternAsia
# 194                              Zambia      EasternAfrica
# 195                            Zimbabwe      EasternAfrica
#
#      Surface area (km2)  Population in thousands (2017)  \
# 0              652864.0                         35530.0
# 1               28748.0                          2930.0
# 2             2381741.0                         41318.0
# ...

# %%
data.head()
# Out:
#                country          Region  Surface area (km2)  \
# 0          Afghanistan    SouthernAsia            652864.0
# 1              Albania  SouthernEurope             28748.0
# 2              Algeria  NorthernAfrica           2381741.0
# 3               Angola    MiddleAfrica           1246700.0
# 4  Antigua and Barbuda       Caribbean               442.0
#
#    Population in thousands (2017)  GDP per capita (current US$)  \
# 0                         35530.0                         623.2
# 1                          2930.0                        3984.2
# 2                         41318.0                        4154.1
# 3                         29784.0                        4714.1
# 4                           102.0                       14764.5
#
#    Agricultural production index   International trade: Imports (million US$)
# 0                           125.0                                      3568.0
# ...

# %% [markdown]
# # 1. Count of countries

# %%
data["country"].count()
# Out:
# 196

# %% [markdown]
# # 2. Data Visualizations

# %% [markdown]
# # 1. Graph of top 10 countries based on population

# %%
plt.figure(figsize=(10,8))
sns.barplot(x='country',y='Population in thousands (2017)',data=data.sort_values('Population in thousands (2017)',ascending=False).head(10),color='black')
plt.title('Top 10 countries based on Population in thousands (2017)',fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Population in thousands (2017)',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 2. Graph of top 10 countries based on surface area

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="country" , y="Surface area (km2)" ,data=data.sort_values("Surface area (km2)" ,ascending=False).head(10) ,color="blue")
plt.title("Top 10 countries based on Surface area(km2)" , fontsize=15)
plt.xlabel('Country',fontsize=15)
plt.ylabel('Surface area(km2) ',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # 3.Graph of least 10 countries based on International trade: Imports (million US$)

# %%
data1=data.nsmallest(10,["International trade: Imports (million US$)"])
data1
# Out:
#                               country         Region  Surface area (km2)  \
# 181                            Tuvalu      Polynesia                26.0
# 118                        Montserrat      Caribbean               103.0
# 115  Micronesia (Federated States of)     Micronesia               702.0
# 111                  Marshall Islands     Micronesia               181.0
# 43                       Cook Islands      Polynesia               236.0
# 94                           Kiribati     Micronesia               726.0
# 151             Sao Tome and Principe   MiddleAfrica               964.0
# 34           Central African Republic   MiddleAfrica            622984.0
# 133                             Palau     Micronesia               459.0
# 41                            Comoros  EasternAfrica              2235.0
#
#      Population in thousands (2017)  GDP per capita (current US$)  \
# 181                            11.0                        3362.4
# ...

# %%
plt.figure(figsize=(10,8))
x=data1["country"]
y=data1["International trade: Imports (million US$)"]
plt.plot(x,y)
plt.title("Least 10 countries based on International trade: Imports (million US$)" , fontsize=15)
plt.xlabel("country" , fontsize=13)
plt.ylabel("International trade: Imports (million US$)" , fontsize=13)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # 4.Graph of least 5 countries based on  GDP per capita (current US$)

# %%
plt.figure(figsize=(10,8))
sns.barplot(x="country" , y="GDP per capita (current US$)" ,data=data.sort_values("GDP per capita (current US$)",ascending=True).head(5) ,color="red")
plt.title("Least 5 countries based on GDP per capita (current US$)" , fontsize=15)
plt.xlabel("country" , fontsize=13)
plt.ylabel("GDP per capita (current US$)", fontsize=13)
plt.xticks(rotation=90)
plt.grid()
plt.show()

# %% [markdown]
# # 3. Countries with respect to regions

# %%
data.groupby("Region")[["country"]].count()
# Out:
#                    country
# Region
# Caribbean               16
# CentralAmerica           8
# CentralAsia              5
# EasternAfrica           17
# EasternAsia              7
# EasternEurope           10
# Melanesia                5
# Micronesia               4
# MiddleAfrica             9
# NorthernAfrica           5
# NorthernAmerica          4
# NorthernEurope          10
# Oceania                  2
# Polynesia                5
# South-easternAsia       11
# SouthAmerica            12
# SouthernAfrica           5
# SouthernAsia             9
# SouthernEurope          12
# WesternAfrica           15
# WesternAsia             18
# WesternEurope            7

# %% [markdown]
# # 4.On average which region has the highest

# %% [markdown]
# # a.GDP per capita(current US$)

# %%
top_GDP=data.groupby("Region")[["GDP per capita (current US$)"]].mean()
top_GDP.sort_values("GDP per capita (current US$)", ascending=False)
# Out:
#                    GDP per capita (current US$)
# Region
# NorthernAmerica                    57659.000000
# WesternEurope                      55387.128571
# Oceania                            44823.250000
# NorthernEurope                     42098.220000
# EasternAsia                        27967.614286
# WesternAsia                        17013.938889
# Caribbean                          15135.562500
# SouthernEurope                     14462.741667
# South-easternAsia                  10299.027273
# EasternEurope                       9292.490000
# Melanesia                           9261.960000
# Polynesia                           8686.520000
# SouthAmerica                        8499.775000
# CentralAmerica                      6348.137500
# Micronesia                          5008.300000
# CentralAsia                         4329.880000
# SouthernAfrica                      4191.900000
# NorthernAfrica                      3934.960000
# ...

# %%
top_GDP.nlargest(1,"GDP per capita (current US$)")
# Out:
#                  GDP per capita (current US$)
# Region
# NorthernAmerica                       57659.0

# %% [markdown]
# # 4.b International trade:imports(million US$)

# %%
top_ITI=data.groupby("Region")[["International trade: Imports (million US$)"]].mean()
top_ITI.sort_values("International trade: Imports (million US$)" , ascending=False)
# Out:
#                    International trade: Imports (million US$)
# Region
# NorthernAmerica                                 663552.250000
# EasternAsia                                     451995.000000
# WesternEurope                                   407498.428571
# NorthernEurope                                  113407.200000
# Oceania                                         112914.500000
# South-easternAsia                                98324.636364
# EasternEurope                                    85243.900000
# SouthernEurope                                   76666.666667
# SouthernAsia                                     58199.333333
# CentralAmerica                                   57031.500000
# WesternAsia                                      46025.555556
# NorthernAfrica                                   35034.400000
# SouthAmerica                                     32885.666667
# SouthernAfrica                                   18005.600000
# ...

# %%
top_ITI.nlargest(1,"International trade: Imports (million US$)")
# Out:
#                  International trade: Imports (million US$)
# Region
# NorthernAmerica                                   663552.25

# %% [markdown]
# # 5. Consistent region with respect to GDP per capita(current US$)

# %%
GDP_data=data.groupby("Region")[["GDP per capita (current US$)"]].std()
GDP_data.sort_values("GDP per capita (current US$)" , ascending=False)
# Out:
#                    GDP per capita (current US$)
# Region
# EasternAsia                        27485.120923
# NorthernAmerica                    25749.619445
# WesternEurope                      24770.467728
# NorthernEurope                     20671.030185
# WesternAsia                        18812.151459
# South-easternAsia                  16311.810656
# Caribbean                          14579.371326
# Melanesia                          13855.842686
# SouthernEurope                      9541.703216
# Oceania                             9233.329638
# Polynesia                           6956.250286
# EasternEurope                       5415.488739
# MiddleAfrica                        5274.846281
# Micronesia                          4820.669694
# SouthAmerica                        4273.707394
# CentralAmerica                      4180.440883
# CentralAsia                         4152.215490
# EasternAfrica                       3716.131770
# ...

# %%
GDP_data.nsmallest(1,"GDP per capita (current US$)")
# Out:
#                GDP per capita (current US$)
# Region
# WesternAfrica                    815.095399
