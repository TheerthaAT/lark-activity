# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\user\Desktop\Telco-Customer-Churn.xlsx")
# Out:
# F:\anaconda\New folder\lib\site-packages\openpyxl\worksheet\_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No     1.0
# 1     5575-GNVDE    Male            0.0      No         No    34.0
# 2     3668-QPYBK    Male            0.0      No         No     2.0
# 3     7795-CFOCW    Male            0.0      No         No    45.0
# 4     9237-HQITU  Female            0.0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes    24.0
# 7039  2234-XADUH  Female            0.0     Yes        Yes    72.0
# 7040  4801-JZAZL  Female            0.0     Yes        Yes    11.0
# 7041  8361-LTMKD    Male            1.0     Yes         No     4.0
# 7042  3186-AJIEK    Male            0.0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female            0.0     Yes         No     1.0           No
# 1  5575-GNVDE    Male            0.0      No         No    34.0          Yes
# 2  3668-QPYBK    Male            0.0      No         No     2.0          Yes
# 3  7795-CFOCW    Male            0.0      No         No    45.0           No
# 4  9237-HQITU  Female            0.0      No         No     2.0          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # 1.Compare churn count with respect to gender

# %%
plt.figure(figsize=(8,6))
sns.countplot(x="gender" , hue="Churn" , data=data)
plt.title("Churn count VS Gender")
# Out:
# Text(0.5, 1.0, 'Churn count VS Gender')

# %% [markdown]
# # 2.Find out how many female senior citizens there in the dataset

# %%
data1=data[(data['gender']=='Female') & (data['SeniorCitizen']==1)]
data1['gender'].count()
# Out:
# 568

# %%
plt.figure(figsize=(4,8))
sns.countplot(x=data1['gender'])
plt.title("Count of female senior citizens ")
# Out:
# Text(0.5, 1.0, 'Count of female senior citizens ')

# %% [markdown]
# # 3.Compare 'tenure' with 'Total charges'

# %%
plt.figure(figsize=(8,6))
plt.scatter(data['tenure'] , data['TotalCharges'] , s=10 , c='black')
plt.title("tenure VS Total charges")
plt.xlabel('tenure')
plt.ylabel('Total Charges')
# Out:
# Text(0, 0.5, 'Total Charges')

# %% [markdown]
# # 4.Find out which contract is preferred by the senior citizen

# %%
data1
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 30    3841-NFECX  Female            1.0     Yes         No    71.0
# 50    8012-SOUDQ  Female            1.0      No         No    43.0
# 52    6575-SUVOI  Female            1.0     Yes         No    25.0
# 53    7495-OOKFY  Female            1.0     Yes         No     8.0
# 54    4667-QONEA  Female            1.0     Yes        Yes    60.0
# ...          ...     ...            ...     ...        ...     ...
# 6993  6583-QGCSI  Female            1.0     Yes         No    50.0
# 7008  1980-KXVPM  Female            1.0      No         No     3.0
# 7010  0723-DRCLG  Female            1.0     Yes         No     1.0
# 7023  1035-IPQPU  Female            1.0     Yes         No    63.0
# 7029  2235-DWLJU  Female            1.0      No         No     6.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 30            Yes               Yes     Fiber optic            Yes  ...
# ...

# %%
plt.figure(figsize=(8,6))
sns.countplot(data1['Contract'])
plt.title('Contract preference of SeniorCitizens', fontsize=15)
# Out:
# F:\anaconda\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Contract preference of SeniorCitizens')

# %% [markdown]
# # 5.Comment on your finds on Payment Method

# %%
plt.figure(figsize=(10,8))
sns.countplot(x='PaymentMethod', hue='gender' , data=data)
plt.title("Payment method VS Gender" , fontsize=15)
# Out:
# Text(0.5, 1.0, 'Payment method VS Gender')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data['PaymentMethod'])
plt.title('Payment methods')
# Out:
# F:\anaconda\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Payment methods')

# %%
plt.figure(figsize=(10,6))
sns.countplot(data1['PaymentMethod'])
plt.title('PaymentMethod preference of SeniorCitizen' , fontsize=15)
# Out:
# F:\anaconda\New folder\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'PaymentMethod preference of SeniorCitizen')
